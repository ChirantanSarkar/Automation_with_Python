# %% [markdown]
# # Web Scraping:

# %%
# Libraries
! pip install lxml
! pip install fake-useragent

# %%
from io import StringIO
from fake_useragent import UserAgent
import pandas as pd
import requests

url="https://en.wikipedia.org/wiki/Cinema_of_the_United_States"
headers={"User-Agent": UserAgent().random} #Mimics as a human using a browser
download=requests.get(url,headers=headers) #Downloads the data from web
data=StringIO(download.text) #Turns it into readable text
df=pd.read_html(data)
df[0].head()
# Out:
#              Cinema of the United States (Hollywood)  \
# 0  The Hollywood Sign in the Hollywood Hills, oft...
# 1                                     No. of screens
# 2                                       • Per capita
# 3                                  Main distributors
# 4                   Produced feature films (2016)[2]
#
#            Cinema of the United States (Hollywood).1
# 0  The Hollywood Sign in the Hollywood Hills, oft...
# 1                                   40,393 (2017)[1]
# 2                           14 per 100,000 (2017)[1]
# 3  Disney (Walt Disney Pictures, 20th Century Stu...
# 4                   Produced feature films (2016)[2]
